# %%
# Age Checker
age = int(input("Enter your age here: "))
if age >=18:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter your age here:  18
# Access Granted

# %%
# Age Checker
age = int(input("Enter your age here: "))
if age >=18:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter your age here:  17
# Access Denied
